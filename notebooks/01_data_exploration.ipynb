# %%
# !pip install geopandas

import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

print("Projektstart erfolgreich!")
# Out:
# Collecting geopandas
#   Downloading geopandas-1.1.3-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy>=1.24 in c:\users\marijke\anaconda3\lib\site-packages (from geopandas) (2.3.5)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.12.1-cp313-cp313-win_amd64.whl.metadata (6.0 kB)
# Requirement already satisfied: packaging in c:\users\marijke\anaconda3\lib\site-packages (from geopandas) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\marijke\anaconda3\lib\site-packages (from geopandas) (2.3.3)
# Requirement already satisfied: pyproj>=3.5.0 in c:\users\marijke\anaconda3\lib\site-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\marijke\anaconda3\lib\site-packages (from geopandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\marijke\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\marijke\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\marijke\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in c:\users\marijke\anaconda3\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2026.5.20)
# Requirement already satisfied: six>=1.5 in c:\users\marijke\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
# Downloading geopandas-1.1.3-py3-none-any.whl (342 kB)
# Downloading pyogrio-0.12.1-cp313-cp313-win_amd64.whl (22.9 MB)
#    ---------------------------------------- 0.0/22.9 MB ? eta -:--:--
#    - -------------------------------------- 0.8/22.9 MB 3.1 MB/s eta 0:00:08
#    -- ------------------------------------- 1.6/22.9 MB 3.9 MB/s eta 0:00:06
#    ---- ----------------------------------- 2.6/22.9 MB 3.9 MB/s eta 0:00:06
#    ----- ---------------------------------- 3.4/22.9 MB 4.0 MB/s eta 0:00:05
#    ------- -------------------------------- 4.2/22.9 MB 4.0 MB/s eta 0:00:05
#    -------- ------------------------------- 5.0/22.9 MB 4.1 MB/s eta 0:00:05
#    --------- ------------------------------ 5.5/22.9 MB 3.7 MB/s eta 0:00:05
#    ---------- ----------------------------- 6.3/22.9 MB 3.7 MB/s eta 0:00:05
#    ------------ --------------------------- 7.1/22.9 MB 3.7 MB/s eta 0:00:05
#    ------------- -------------------------- 7.9/22.9 MB 3.7 MB/s eta 0:00:05
#    --------------- ------------------------ 8.7/22.9 MB 3.7 MB/s eta 0:00:04
#    ---------------- ----------------------- 9.4/22.9 MB 3.7 MB/s eta 0:00:04
#    ------------------ --------------------- 10.5/22.9 MB 3.8 MB/s eta 0:00:04
#    ------------------- -------------------- 11.3/22.9 MB 3.9 MB/s eta 0:00:04
#    --------------------- ------------------ 12.1/22.9 MB 3.9 MB/s eta 0:00:03
#    ---------------------- ----------------- 12.8/22.9 MB 3.8 MB/s eta 0:00:03
#    ----------------------- ---------------- 13.6/22.9 MB 3.9 MB/s eta 0:00:03
#    ------------------------- -------------- 14.4/22.9 MB 3.8 MB/s eta 0:00:03
#    -------------------------- ------------- 15.5/22.9 MB 3.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 16.3/22.9 MB 3.9 MB/s eta 0:00:02
#    ------------------------------ --------- 17.3/22.9 MB 3.9 MB/s eta 0:00:02
#    ------------------------------- -------- 18.1/22.9 MB 4.0 MB/s eta 0:00:02
#    --------------------------------- ------ 19.1/22.9 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 19.9/22.9 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------ --- 21.0/22.9 MB 4.0 MB/s eta 0:00:01
#    -------------------------------------- - 22.0/22.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  22.8/22.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 22.9/22.9 MB 3.9 MB/s  0:00:05
# Installing collected packages: pyogrio, geopandas
#
#    ---------------------------------------- 0/2 [pyogrio]
#    ---------------------------------------- 0/2 [pyogrio]
#    ---------------------------------------- 0/2 [pyogrio]
#    ---------------------------------------- 0/2 [pyogrio]
#    ---------------------------------------- 0/2 [pyogrio]
#    ---------------------------------------- 0/2 [pyogrio]
#    ---------------------------------------- 0/2 [pyogrio]
#    ---------------------------------------- 0/2 [pyogrio]
#    -------------------- ------------------- 1/2 [geopandas]
#    -------------------- ------------------- 1/2 [geopandas]
#    -------------------- ------------------- 1/2 [geopandas]
#    -------------------- ------------------- 1/2 [geopandas]
#    -------------------- ------------------- 1/2 [geopandas]
#    -------------------- ------------------- 1/2 [geopandas]
#    -------------------- ------------------- 1/2 [geopandas]
#    -------------------- ------------------- 1/2 [geopandas]
#    -------------------- ------------------- 1/2 [geopandas]
#    -------------------- ------------------- 1/2 [geopandas]
#    ---------------------------------------- 2/2 [geopandas]
#
# Successfully installed geopandas-1.1.3 pyogrio-0.12.1
# Projektstart erfolgreich!
